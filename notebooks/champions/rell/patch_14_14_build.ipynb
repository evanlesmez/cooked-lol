# %% [raw]
# ---
# title: "Patch 14.14 Rell Top build"
# jupyter: python3
# ---

# %% [markdown]
# <img src="https://static.wikia.nocookie.net/leagueoflegends/images/2/21/Rell_Render.png" style="height:200px; margin: 0 30px">
#
# [Rell](https://leagueoflegends.fandom.com/wiki/Rell/LoLhttps://leagueoflegends.fandom.com/wiki/Rell/LoL) may be a decent top laner.
# She is already a meta support.
# Her stacking armor and magic resist shred passive signal that she is a good all in champ.
# Her AP ratios are not great and she has long CDs.
# However, in her unmounted form she gains attack speed, a sheild, and bonus armor and magic resist.
#
#
# ![image.png](attachment:9cc43160-05c8-4040-a2ad-8d875e216f63.png)
# ![image.png](attachment:78c1f086-d280-415a-a0f9-e9433f9f922f.png)
#
# In a teamfight, the Rell passive could stack a ton shredding multiple enemies resistances and giving her a ton of bonus armor and mr, especially against tanks.
# Her passive is similar to terminus which In a teamfight, the Rell passive could stack a ton shredding multiple enemies resistances and giving her a ton of bonus armor and mr, especially against tanks.
# Her passive is similar to terminus which made me think it could be a good item to build especially for extended fights in a Press the Attack rune setup.
# Note that her W sheild scales with bonus max health.
#
# ![image.png](attachment:de15f895-2b3f-451f-931c-d57559334f33.png)
#
#
# She has low mana costs that do not ever increase with ranking up abilities.
# Her CD only lowers on Q with maxing.
#
# **Ability max order**
# Q -> W -> E
#
# E only adds move speed as the damage buff is neglible.
#
#
# ### Pros
# - Useful all in passive
# - useful unmounted state
# - strong base damages
# - high cc
# - great scaling on ult
# - no scaling mana costs
#
# ### Cons
# - poor waveclear
# - high ability cooldowns
# - not great scaling on abilities
# - slow attack speed windup especially mounted
# - low mobility once umounted while waiting for w to come back up

# %%
from cooked_lol import utils, constants
from cooked_lol.items import boots

# %% [markdown]
# ## Useful stats
#
# AP is decent but her ratios are not great as well as her cooldowns.
# Mana is ok but her costs are not too bad.
# Her base damage are decent so flat magic pen is ok.
# Health is useful for her sheild scaling and tankiness in general.
# Haste would helpful for her long cooldowns.
# Armor and MR are great because they both scale her unmounted form.
# AD and attack speed are useful for her unmounted form for extended fights.

# %% [markdown]
# ## Boots rush
#
# Her base damages are pretty good on all abilities so pen boots will add some good base damage.
# Attack speed boots are nice for an all in setup like Press the Attack.
# Haste boots are also nice since her cooldowns are longs.
# See the [Boots](../../systems/season_14/boots_14_14.ipynb) notebook for the gold efficiency breakdown as attack speed boots are a cut ahead of the other if your champ can make use of them.
#
# A note on gold efficiencies though:
# Even though an item might be less "gold efficient", it still may be more efficient on certain champs.
# For example, Nautilus only does AP damage on spells so the magic pen from pen boots makes every ability more useful, especially if building some haste and AP in other items.

# %% [markdown]
# ## Builds
#
# ### Items of interest
#
# [Zeke's convergence](https://leagueoflegends.fandom.com/wiki/Zeke%27s_Convergence) gives all useful stats for and the unique is basically rell's ultimate again.
# Helpful with pretty much any setup.
#
# [Terminus]() similar to her passive, scales
#
# [Liandry's]() tank shredder and all in scaling.
#
# [Riftmaker]() all in scales.
#
# [Stridebreaker]() waveclear with tiamat and health and stick on target.
#
# [Navori]() reduces her ability cd on each hit.
#
# [Jak'sho]() scales well with her stats.
#
# [Frozen heart]() mana and attack speed slow are nice.
#
# [Malignance]() ult is secerety 110% AP scaling. The mana is also nice and haste.
#
# [Nashor's Tooth]() haste, attack speed, onhit all nice
#
#
# ### Full AP
#
# #### Arcane comet: Pen boots, malignance, nashor's tooth, liandry's or riftmaker
#
# #### Arcane Comet: Pen boots, luden's companion, liandry's, riftmaker
#
# #### Arcane Comet: Haste boots, nashor's, riftmaker, liandry's
#
# ### Ult all in
#
# #### Arcane comet: Pen boots, malignance, zeke's, liandry's
#
# ### Press the Attack
#
# #### Attack speed boots, stridebreaker, terminus, zeke's
#
# ### Tank hybrid
# #### Any boots, Cinder item,

# %% [markdown]
# ## Trade patterns
#
# While mounted, E speed up into Q to shatter a shield and stun, then W into basic attacks if possible or desired.
# Otherwise, can E to close gap, W, basic attack Q basic attack and almost have fully stacked Press the Attack.

# %% [markdown]
# ## Questions
#
# Does onhit from titanic spread rell passive?
# How can you spread Rell Passive?
# Does terminus stack with abilities?
